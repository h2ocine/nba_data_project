# %%
import bs4
import pandas as pd
import numpy as np
from urllib import request

# %%
def get_seasons_urls(url : str) -> str:
    """
    Get a list of season URLs.
    """
    # Open the URL of the NBA Stats seasons list
    response = request.urlopen(url)
    html = response.read()

    # Get the HTML text of the NBA Stats website
    soup = bs4.BeautifulSoup(html, "lxml")

    # Find the <h2> tags
    h2_tags = soup.find_all('h2')
    h2_soup = bs4.BeautifulSoup(str(h2_tags), 'lxml')

    # Find the <a> tags
    a_tags = h2_soup.find_all('a')

    # Get the list of season URLs
    urls = [a['href'] for a in a_tags]

    return urls

# %%
def get_table_data(url : str) -> pd.DataFrame:
    """
    Returns a data frame of the table in the url
    """

    # Open the URL and read the HTML content
    response = request.urlopen(url)
    html = response.read()

    # Create BeautifulSoup object to parse the HTML
    soup = bs4.BeautifulSoup(html, "lxml")

    # Find the <article> tags
    article_tag = soup.find('article')
    article_soup = bs4.BeautifulSoup(str(article_tag), 'lxml')

    # Find the <table> tag
    table_tag = article_soup.find('table')
    table_soup = bs4.BeautifulSoup(str(table_tag))

    # Find the <thead> tag
    thead_tag = table_soup.find('thead')
    thead_soup = bs4.BeautifulSoup(str(thead_tag))

    # Find all the <th> tags within the <thead> tag
    th_head_tag = thead_soup.find_all('th')

    # Get the column names
    columns_name = [column.get_text() for column in th_head_tag]

    # Find all the <tr> tags within the <table> tag
    tr_tag = table_soup.find_all('tr')

    # Get the data
    data = [] 
    lines_list = tr_tag[1:]

    rank = 1
    for tr in lines_list:
        tr_soup = bs4.BeautifulSoup(str(tr))
        td_tags = tr_soup.find_all('td')

        attributes = []
        for td in td_tags:
            attribute = td.get_text()
            if attribute == "":  # If empty, it's the rank column
                attributes.append(str(rank))
                rank += 1
            else:
                attributes.append(attribute)

        data.append(attributes)

    # Get the data into a dataframe
    data_array = np.asarray(data)
    df = pd.DataFrame(data, columns=columns_name)

    # Add the Title of the dataframe (Season years + Player/Team/Referee stats) 
    h1_tag = article_soup.find('h1')
    df['Title'] = h1_tag.get_text() # This will add the title in each column
    
    return df

# %%
def upload_data(urls_list : list[str]) -> pd.DataFrame:
    """
    Uploads data from a list of URLs and returns a list of DataFrames.
    """
    data_list = []
    for url in urls_list:
        # Retrieve table data from the URL
        df = get_table_data(url)
        # Print a success message with the title and URL
        print(f"{df['Title'][0]} data uploaded successfully from {url}")
        # Append the DataFrame to the data_list
        data_list.append(df)
    return data_list

# %%
# Set the length of each URL to get only the URL we want (in this case, all the URLs we want have the same size in each category)
len_url_players = len("https://www.nbastuffer.com/2023-2024-nba-player-stats/")
len_url_teams = len("https://www.nbastuffer.com/2023-2024-nba-team-stats/")
len_url_referees = len("https://www.nbastuffer.com/2023-2024-nba-referee-stats/")

# Get the menu URL where the seasons URLs are
players_menu_url = "https://www.nbastuffer.com/nba-stats/player/"
teams_menu_url = "https://www.nbastuffer.com/nba-stats/team/"
referees_menu_url = "https://www.nbastuffer.com/nba-stats/referee/"

# Get all the seasons URLs for players
players_urls_list = [url for url in get_seasons_urls(players_menu_url) if len(url) == len_url_players]

# Get all the seasons URLs for teams
teams_urls_list = [url for url in get_seasons_urls(teams_menu_url) if len(url) == len_url_teams]

# Get all the seasons URLs for referees
referees_urls_list = [url for url in get_seasons_urls(referees_menu_url) if len(url) == len_url_referees]

# %%
# Upload players' stats data
players_list = upload_data(players_urls_list)

# Upload teams' stats data
teams_list = upload_data(teams_urls_list)

# Upload referees' stats data
referee_list = upload_data(referees_urls_list)
# Out:
# 2023-2024 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2023-2024-nba-player-stats/
# 2022-2023 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2022-2023-nba-player-stats/
# 2021-2022 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2021-2022-nba-player-stats/
# 2020-2021 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2020-2021-nba-player-stats/
# 2019-2020 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2019-2020-nba-player-stats/
# 2018-2019 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2018-2019-nba-player-stats/
# 2017-2018 NBA Player Stats data uploaded successfully from https://www.nbastuffer.com/2017-2018-nba-player-stats/
# 2023-2024 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2023-2024-nba-team-stats/
# 2022-2023 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2022-2023-nba-team-stats/
# 2021-2022 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2021-2022-nba-team-stats/
# 2020-2021 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2020-2021-nba-team-stats/
# 2019-2020 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2019-2020-nba-team-stats/
# 2018-2019 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2018-2019-nba-team-stats/
# 2017-2018 NBA Advanced Team Stats data uploaded successfully from https://www.nbastuffer.com/2017-2018-nba-team-stats/
# 2023-2024 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2023-2024-nba-referee-stats/
# 2022-2023 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2022-2023-nba-referee-stats/
# 2021-2022 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2021-2022-nba-referee-stats/
# 2020-2021 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2020-2021-nba-referee-stats/
# 2019-2020 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2019-2020-nba-referee-stats/
# 2018-2019 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2018-2019-nba-referee-stats/
# 2017-2018 NBA Referee Stats data uploaded successfully from https://www.nbastuffer.com/2017-2018-nba-referee-stats/

# %%
# Data Frame visualisation

# Print the first three lines of each DataFrame in players_list
print("Players Data:")
for df in players_list:
    print(df.head(3))

# Print the first three lines of each DataFrame in teams_list
print("Teams Data:")
for df in teams_list:
    print(df.head(3))

# Print the first three lines of each DataFrame in referee_list
print("Referees Data:")
for df in referee_list:
    print(df.head(3))
# Out:
# Players Data:
#   RANK          NAME TEAM POS   AGE  GP   MPG  USG%   TO%  FTA  ...  SPG  BPG  \
# 0    1  LeBron James  Lal   F  39.1  48    35    29  15.2  266  ...  1.3  0.6
# 1    2    Chris Paul  Gol   G  38.8  32  27.6  14.3  13.4   42  ...  1.1  0.1
# 2    3    Kyle Lowry  Mia   G  37.9  37    28  13.3  17.7   42  ...  1.1  0.4
#
#    TPG   P+R   P+A P+R+A    VI   ORtg   DRtg                       Title
# 0  3.2  32.1  32.6  39.9  12.8  116.8  113.2  2023-2024 NBA Player Stats
# 1  1.2  12.7  16.1  19.9   9.1  127.8  112.9  2023-2024 NBA Player Stats
# 2  1.4  11.6  12.2  15.6   6.9  115.6  107.5  2023-2024 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK              NAME TEAM  POS   AGE  GP   MPG  USG%   TO%  FTA  ...  SPG  \
# 0    1  Precious Achiuwa  Tor    F  23.6  55  20.7  19.3  12.7  124  ...  0.6
# 1    2      Steven Adams  Mem    C  29.7  42    27  14.6  23.1  129  ...  0.9
# 2    3       Bam Adebayo  Mia  C-F  25.7  75  34.6  25.3  14.4  402  ...  1.2
#
#    BPG  TPG   P+R   P+A P+R+A   VI   ORtg   DRtg                       Title
# 0  0.5  1.1  15.2  10.1  16.1  7.1  112.3  106.9  2022-2023 NBA Player Stats
# 1  1.1  1.9  20.1  10.9  22.5    9  118.1  103.2  2022-2023 NBA Player Stats
# 2  0.8  2.5  29.6  23.6  32.8  9.8    116  105.6  2022-2023 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK         FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0    1  Precious Achiuwa  Tor    F  22.56  73  23.6
# 1    2      Steven Adams  Mem    C  28.73  76  26.3
# 2    3       Bam Adebayo  Mia  C-F  24.73  56  32.6
#
#   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               49.2
# 1                                               54.8
# 2                                               67.9
#
#   USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               18.5
# 1                                                 12
# 2                                                 25
#
#   TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                               11.3
# 1                                               19.6
# 2                                               14.4
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               14.9
# 1                                               19.9
# 2                                               17.5
#
#   APGAssistsAssists per game.  \
# 0                         1.1
# 1                         3.4
# 2                         3.4
#
#   AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                                6.9
# 1                                               16.1
# 2                                               17.5
#
#   SPGStealsSteals per game. BPGBlocksBlocks per game.  \
# 0                      0.51                      0.56
# 1                      0.87                      0.79
# 2                      1.43                      0.79
#
#   TOPGTurnoversTurnovers per game.  \
# 0                             1.15
# 1                             1.51
# 2                             2.64
#
#   VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                6.8
# 1                                                9.4
# 2                                               10.7
#
#   ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              105.4
# 1                                              124.7
# 2                                              117.2
#
#   DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.  \
# 0                                                104
# 1                                              103.9
# 2                                               98.2
#
#                         Title
# 0  2021-2022 NBA Player Stats
# 1  2021-2022 NBA Player Stats
# 2  2021-2022 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK         FULL NAME TEAM POS    AGE  GP   MPG  \
# 0    1  Precious Achiuwa  Mia   F  21.66  61  12.1
# 1    2      Jaylen Adams  Mil   G  25.03   7   2.6
# 2    5      Steven Adams  Nor   C  27.83  58  27.7
#
#   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               25.2
# 1                                                5.4
# 2                                               57.6
#
#   USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               19.5
# 1                                               18.5
# 2                                               11.7
#
#   TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                               13.5
# 1                                                  0
# 2                                               17.7
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               16.1
# 1                                                8.7
# 2                                               17.4
#
#   APGAssistsAssists per game.  \
# 0                         0.5
# 1                         0.3
# 2                         1.9
#
#   AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                                6.1
# 1                                               12.6
# 2                                                9.1
#
#   SPGStealsSteals per game. BPGBlocksBlocks per game.  \
# 0                      0.33                      0.46
# 1                         0                         0
# 2                      0.93                      0.66
#
#   TOPGTurnoversTurnovers per game.  \
# 0                              0.7
# 1                                0
# 2                             1.36
#
#   VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                6.7
# 1                                                5.1
# 2                                                7.3
#
#   ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              106.8
# 1                                                  3
# 2                                              119.7
#
#   DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.  \
# 0                                               99.7
# 1                                                  4
# 2                                              107.8
#
#                         Title
# 0  2020-2021 NBA Player Stats
# 1  2020-2021 NBA Player Stats
# 2  2020-2021 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK          FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0    1       Steven Adams  Okc    C  27.07  63  26.7
# 1    2        Bam Adebayo  Mia  C-F  23.08  72  33.6
# 2    3  LaMarcus Aldridge  San  F-C  35.07  53  33.1
#
#   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               55.6
# 1                                               69.9
# 2                                               68.9
#
#   USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               17.3
# 1                                               21.2
# 2                                               23.4
#
#   TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                               14.4
# 1                                               17.5
# 2                                                7.8
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               19.2
# 1                                                 17
# 2                                                 12
#
#   APGAssistsAssists per game.  \
# 0                         2.3
# 1                         5.1
# 2                         2.4
#
#   AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                               13.2
# 1                                               24.2
# 2                                               11.4
#
#   SPGStealsSteals per game. BPGBlocksBlocks per game.  \
# 0                      0.81                      1.06
# 1                      1.14                      1.29
# 2                      0.68                      1.64
#
#   TOPGTurnoversTurnovers per game.  \
# 0                             1.51
# 1                             2.82
# 2                              1.4
#
#   VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                9.2
# 1                                               11.2
# 2                                                8.4
#
#   ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                                122
# 1                                              116.2
# 2                                              114.7
#
#   DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.  \
# 0                                              101.9
# 1                                              102.2
# 2                                              109.1
#
#                         Title
# 0  2019-2020 NBA Player Stats
# 1  2019-2020 NBA Player Stats
# 2  2019-2020 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK    FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0    1   Marc Gasol  Tor    C  34.37  24  30.6
# 1    2  Danny Green  Tor  G-F  31.98  24  28.5
# 2    3  Serge Ibaka  Tor  F-C  29.74  24  20.8
#
#   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               63.8
# 1                                               59.4
# 2                                               43.4
#
#   USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               13.6
# 1                                               12.6
# 2                                               21.4
#
#   Tor%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                                9.5
# 1                                               13.6
# 2                                               10.6
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               11.5
# 1                                                  7
# 2                                               15.8
#
#   APGAssistsAssists per game.  \
# 0                           3
# 1                         1.1
# 2                         0.9
#
#   AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                               14.7
# 1                                                5.4
# 2                                                7.4
#
#   SPGStealsSteals per game. BPGBlocksBlocks per game.  \
# 0                      0.88                      1.08
# 1                      1.29                      0.46
# 2                      0.46                      0.96
#
#   TOPGTurnoversTurnovers per game.  \
# 0                             0.88
# 1                             1.08
# 2                             1.04
#
#   VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                7.4
# 1                                                4.2
# 2                                                7.1
#
#   ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              118.4
# 1                                               97.4
# 2                                              105.5
#
#   DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.  \
# 0                                               97.2
# 1                                              101.6
# 2                                               91.9
#
#                         Title
# 0  2018-2019 NBA Player Stats
# 1  2018-2019 NBA Player Stats
# 2  2018-2019 NBA Player Stats
#
# [3 rows x 30 columns]
#   RANK      FULL NAME TEAM POS AGE  GP  MPG  \
# 0    1   Aaron Brooks  Min  PG  33   2  1.4
# 1    4  Aaron Jackson  Hou   F  31   7  2.4
# 2    7    Abdel Nader  Bos  SF  24  11    3
#
#   MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                2.8
# 1                                                5.1
# 2                                                6.3
#
#   USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               63.7
# 1                                               17.8
# 2                                               25.5
#
#   TOrTurnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                                  0
# 1                                              0.291
# 2                                              0.107
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
#
#   TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                                  0
# 1                                               13.1
# 2                                                  5
#
#   APGAssistsAssists per game.  \
# 0                           0
# 1                         0.3
# 2                         0.3
#
#   AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                                  0
# 1                                               17.2
# 2                                               14.3
#
#   SPGStealsSteals per game. BPGBlocksBlocks per game.  \
# 0                         0                         0
# 1                         0                         0
# 2                      0.09                      0.09
#
#   TOPGTurnoversTurnovers per game.  \
# 0                                0
# 1                             0.29
# 2                             0.18
#
#   VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                  0
# 1                                                8.4
# 2                                                6.2
#
#   ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                                  2
# 1                                                  5
# 2                                                  8
#
#   DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.  \
# 0                                                  3
# 1                                                  6
# 2                                                  9
#
#                         Title
# 0  2017-2018 NBA Player Stats
# 1  2017-2018 NBA Player Stats
# 2  2017-2018 NBA Player Stats
#
# [3 rows x 30 columns]
# Teams Data:
#   RANK      TEAM  CONF   DIVISION  GP    PPG   oPPG pDIFF   PACE   oEFF  ...  \
# 0    1   Atlanta  East  Southeast  53  121.7  123.7    -2  101.4    119  ...
# 1    2    Boston  East   Atlantic  53  120.4    111   9.4   98.3  121.3  ...
# 2    3  Brooklyn  East   Atlantic  52  113.9  115.2  -1.3   97.9  115.8  ...
#
#    CONS     A4F   W   L   WIN%  eWIN%  pWIN%     ACH STRK  \
# 0  12.1  -0.062  24  29  0.453  0.434  0.434   0.019    2
# 1  15.3   0.082  41  12  0.774  0.732   0.81   0.042    4
# 2  14.3  -0.003  21  31  0.404  0.467  0.457  -0.063    1
#
#                                Title
# 0  2023-2024 NBA Advanced Team Stats
# 1  2023-2024 NBA Advanced Team Stats
# 2  2023-2024 NBA Advanced Team Stats
#
# [3 rows x 25 columns]
#   RANK      TEAM  CONF   DIVISION  GP    PPG   oPPG  pDIFF   PACE   oEFF  ...  \
# 0    1   Atlanta  East  Southeast   6  115.8  121.2   -5.4  100.7    115  ...
# 1    6    Boston  East   Atlantic  20    112  108.6    3.4   94.9  117.4  ...
# 2   11  Brooklyn  East   Atlantic   4   92.5  103.8  -11.3   89.7  103.1  ...
#
#   CONS     A4F   W  L   WIN%  eWIN%  pWIN%     ACH STRK  \
# 0    5  -0.102   2  4  0.333  0.341  0.322  -0.008   -1
# 1   10   0.055  11  9  0.550  0.596  0.612  -0.046   -1
# 2   15  -0.067   0  4  0.000  0.211  0.128  -0.211   -5
#
#                                Title
# 0  2022-2023 NBA Advanced Team Stats
# 1  2022-2023 NBA Advanced Team Stats
# 2  2022-2023 NBA Advanced Team Stats
#
# [3 rows x 25 columns]
#   RANK      TEAM  CONF   DIVISION  GP  \
# 0    1   Atlanta  East  Southeast   5
# 1    6    Boston  East   Atlantic  24
# 2   11  Brooklyn  East   Atlantic   4
#
#   PTS/GMPoints Per GameAverage points per game  \
# 0                                         97.4
# 1                                        105.5
# 2                                          109
#
#   aPTS/GMPoints Allowed Per GameAverage points allowed per game  \
# 0                                              109.4
# 1                                                102
# 2                                              113.5
#
#   PTS DIFFPoints Differential{(Total Points Scored) - (Total Points Allowed)}/ (Games Played)  \
# 0                                                -12
# 1                                                3.5
# 2                                               -4.5
#
#   PACEPaceEstimate of Possessions Per 48 Minutes  \
# 0                                           95.1
# 1                                           95.2
# 2                                           93.6
#
#   OEFFOffensive EfficiencyPoints scored per 100 possessions.  ...  \
# 0                                              102.4          ...
# 1                                              110.8          ...
# 2                                              116.5          ...
#
#   CONSConsistency RatingConsistency based on game-by-game efficiency differential variation. The higher the team has a consistency rating, the more unpredictable it is.  \
# 0                                                  5
# 1                                                 10
# 2                                                 15
#
#   A4FAdjusted Four FactorsCalculated by applying weights to the differentials of offensive and defensive four factors. A4F explains the specified proportion of variability in wins.  \
# 0                                             -0.005
# 1                                              0.058
# 2                                              0.018
#
#   WWinsThe most important goal in sports, unless your team is not tanking  \
# 0                                                  1
# 1                                                 14
# 2                                                  0
#
#   LLossesTotal count of games lost   WIN%  \
# 0                                4  0.200
# 1                               10  0.583
# 2                                4  0.000
#
#   eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                              0.173
# 1                                              0.588
# 2                                              0.372
#
#   pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                              0.105
# 1                                              0.615
# 2                                              0.352
#
#   ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                              0.027
# 1                                             -0.005
# 2                                             -0.372
#
#   STRKCurrent StreakWinning or losing streak for the season.  \
# 0                                                 L2
# 1                                                 L3
# 2                                                 L4
#
#                                Title
# 0  2021-2022 NBA Advanced Team Stats
# 1  2021-2022 NBA Advanced Team Stats
# 2  2021-2022 NBA Advanced Team Stats
#
# [3 rows x 25 columns]
#   RANK      TEAM  CONF   DIVISION  GP  \
# 0    1   Atlanta  East  Southeast  18
# 1    7    Boston  East   Atlantic   5
# 2   13  Brooklyn  East   Atlantic  12
#
#   PTS/GMPoints Per GameAverage points per game  \
# 0                                        106.3
# 1                                        112.2
# 2                                        112.5
#
#   aPTS/GMPoints Allowed Per GameAverage points allowed per game  \
# 0                                              107.8
# 1                                              123.4
# 2                                              106.2
#
#   PTS DIFFPoints Differential{(Total Points Scored) - (Total Points Allowed)}/ (Games Played)  \
# 0                                               -1.5
# 1                                              -11.2
# 2                                                6.3
#
#   PACEPaceEstimate of Possessions Per 48 Minutes  \
# 0                                           96.8
# 1                                           95.8
# 2                                           96.1
#
#   OEFFOffensive EfficiencyPoints scored per 100 possessions.  ...  \
# 0                                              109.8          ...
# 1                                              117.1          ...
# 2                                              116.1          ...
#
#   CONSConsistency RatingConsistency based on game-by-game efficiency differential variation. The higher the team has a consistency rating, the more unpredictable it is.  \
# 0                                                  5
# 1                                                 11
# 2                                                 17
#
#   A4FAdjusted Four FactorsCalculated by applying weights to the differentials of offensive and defensive four factors. A4F explains the specified proportion of variability in wins.  \
# 0                                             -0.019
# 1                                             -0.091
# 2                                              0.048
#
#   WWinsThe most important goal in sports, unless your team is not tanking  \
# 0                                                 10
# 1                                                  1
# 2                                                  7
#
#   LLossesTotal count of games lost   WIN%  \
# 0                                8  0.556
# 1                                4  0.200
# 2                                5  0.583
#
#   eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                              0.459
# 1                                                0.2
# 2                                              0.687
#
#   pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                                  6
# 1                                                 12
# 2                                                 18
#
#   ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                              0.097
# 1                                                  0
# 2                                             -0.104
#
#   STRKCurrent StreakWinning or losing streak for the season.  \
# 0                                                 L2
# 1                                                 L2
# 2                                                 L2
#
#                                Title
# 0  2020-2021 NBA Advanced Team Stats
# 1  2020-2021 NBA Advanced Team Stats
# 2  2020-2021 NBA Advanced Team Stats
#
# [3 rows x 25 columns]
#   RANK      TEAM  CONF   DIVISION  GP  \
# 0    1  Brooklyn  East   Atlantic   4
# 1    7    Boston  East   Atlantic  17
# 2   13    Dallas  West  Southwest   6
#
#   PTS/GMPoints Per GameAverage points per game  \
# 0                                        105.8
# 1                                        109.4
# 2                                          117
#
#   aPTS/GMPoints Allowed Per GameAverage points allowed per game  \
# 0                                              126.3
# 1                                              104.4
# 2                                              126.7
#
#   PTS DIFFPoints Differential{(Total Points Scored) - (Total Points Allowed)}/ (Games Played)  \
# 0                                              -20.5
# 1                                                  5
# 2                                               -9.7
#
#   PACEPaceEstimate of Possessions Per 48 Minutes  \
# 0                                          103.5
# 1                                           96.5
# 2                                            102
#
#   OEFFOffensive EfficiencyPoints scored per 100 possessions.  ...  \
# 0                                              102.1          ...
# 1                                              111.2          ...
# 2                                              112.7          ...
#
#   CONSConsistency RatingConsistency based on game-by-game efficiency differential variation. The higher the team has a consistency rating, the more unpredictable it is.  \
# 0                                                  5
# 1                                                 11
# 2                                                 17
#
#   A4FAdjusted Four FactorsCalculated by applying weights to the differentials of offensive and defensive four factors. A4F explains the specified proportion of variability in wins.  \
# 0                                             -0.145
# 1                                              0.077
# 2                                             -0.049
#
#   WWinsThe most important goal in sports, unless your team is not tanking  \
# 0                                                  0
# 1                                                 10
# 2                                                  2
#
#   LLossesTotal count of games lost   WIN%  \
# 0                                4  0.000
# 1                                7  0.588
# 2                                4  0.333
#
#   eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                              0.081
# 1                                              0.666
# 2                                              0.265
#
#   pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                                  6
# 1                                                 12
# 2                                                 18
#
#   ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                             -0.081
# 1                                             -0.078
# ...
# 0                                                 11
# 1                                                 12
# 2                                                 16
#
#   LLossesTotal count of games lost   WIN%  \
# 0                                8  0.579
# 1                               10  0.545
# 2                                5  0.762
#
#   eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                              0.518
# 1                                              0.459
# 2                                              0.737
#
#   pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                              0.523
# 1                                              0.441
# 2                                              0.829
#
#   ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                              0.061
# 1                                              0.086
# 2                                              0.025
#
#   STRKCurrent StreakWinning or losing streak for the season.  \
# 0                                                L 2
# 1                                                L 4
# 2                                                W 6
#
#                                Title
# 0  2017-2018 NBA Advanced Team Stats
# 1  2017-2018 NBA Advanced Team Stats
# 2  2017-2018 NBA Advanced Team Stats
#
# [3 rows x 22 columns]
# Referees Data:
#   RANK         REFEREE   ROLE GENDER EXPERIENCE (YEARS) GAMES OFFICIATED  \
# 0    1       JB DeRosa  CHIEF   MALE                  7               33
# 1    2  Mitchell Ervin   CREW   MALE                 10               33
# 2    3     Sean Corbin  CHIEF   MALE                 31               40
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.576                           2.3                 230.8
# 1          0.424                          -1.8                 234.8
# 2           0.45                           0.4                 234.2
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                  39.1                    0.511                    0.489
# 1                  41.5                    0.501                    0.498
# 2                    37                    0.514                    0.485
#
#   FOUL DIFFERENTIAL (Against Road Team) - (Against Home Team)  \
# 0                                                0.8
# 1                                                0.1
# 2                                                1.1
#
#                          Title
# 0  2023-2024 NBA Referee Stats
# 1  2023-2024 NBA Referee Stats
# 2  2023-2024 NBA Referee Stats
#   RANK              REFEREE  ROLE  GENDER EXPERIENCE (YEARS) GAMES OFFICIATED  \
# 0    1          Aaron Smith  CREW    MALE                  8               61
# 1    2            Andy Nagy  CREW    MALE                  4               48
# 2    3  Ashley Moyer-Gleich  CREW  FEMALE                  5               62
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.574                           2.8                 231.2
# 1          0.542                             1                 231.5
# 2          0.548                           1.4                 231.8
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                  38.6                    0.498                    0.501
# 1                  37.8                    0.509                    0.491
# 2                  39.8                    0.503                    0.498
#
#   FOUL DIFFERENTIAL (Against Road Team) - (Against Home Team)  \
# 0                                               -0.1
# 1                                                0.7
# 2                                                0.2
#
#                          Title
# 0  2022-2023 NBA Referee Stats
# 1  2022-2023 NBA Referee Stats
# 2  2022-2023 NBA Referee Stats
#   RANK       REFEREE  ROLE EXPERIENCE\n(YEARS) GAMES OFFICIATED  \
# 0    1    Ray Acosta  CREW                   5               64
# 1    2   Jacyn Goble  CREW                   6               64
# 2    3  Natalie Sago  CREW                   4               63
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.438                        -1.344               222.813
# 1            0.5                         1.438               223.375
# 2          0.524                         2.333               223.952
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                  39.5                   50.316                   49.684
# 1                40.703                   49.559                   50.442
# 2                 39.54                   50.501                   49.498
#
#   FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.  \
# 0                                                0.3
# 1                                               -0.4
# 2                                                0.4
#
#                          Title
# 0  2021-2022 NBA Referee Stats
# 1  2021-2022 NBA Referee Stats
# 2  2021-2022 NBA Referee Stats
#   RANK        REFEREE   ROLE EXPERIENCE\n(YEARS) GAMES OFFICIATED  \
# 0    1  Dedric Taylor   CREW                   8               54
# 1    2    Aaron Smith   CREW                   6               54
# 2    3   James Capers  CHIEF                  26               52
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.463                        -1.056               231.648
# 1          0.593                         0.315               223.315
# 2          0.519                         3.731                 223.5
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                39.407                   50.799                   49.202
# 1                37.019                   50.024                   49.974
# 2                37.481                   49.153                   50.846
#
#   FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.  \
# 0                                                0.6
# 1                                                  0
# 2                                               -0.6
#
#                          Title
# 0  2020-2021 NBA Referee Stats
# 1  2020-2021 NBA Referee Stats
# 2  2020-2021 NBA Referee Stats
#   RANK        REFEREE  TYPE EXPERIENCE\n(YEARS) GAMES OFFICIATED  \
# 0    1      Karl Lane  CREW                  10               54
# 1    2     Tyler Ford  CREW                   6               55
# 2    3  Dedric Taylor  CREW                   7               55
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.574                         3.704                217.37
# 1          0.618                         2.745               221.618
# 2          0.564                         2.036               224.582
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                39.333                   50.189                   49.812
# 1                42.545                   50.855                   49.146
# 2                43.273                   50.126                   49.874
#
#   FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.  \
# 0                                                0.1
# 1                                                0.7
# 2                                                0.1
#
#                          Title
# 0  2019-2020 NBA Referee Stats
# 1  2019-2020 NBA Referee Stats
# 2  2019-2020 NBA Referee Stats
#   RANK        REFEREE  TYPE EXPERIENCE\n(YEARS) GAMES OFFICIATED  \
# 0    1  Mike Callahan  MAIN                  28               15
# 1    2   James Capers  MAIN                  23               14
# 2    3  Tony Brothers  MAIN                  24               13
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0          0.533                         4.133                 218.4
# 1          0.643                             3               217.143
# 2          0.615                         8.077               202.538
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                44.667                       50                       50
# 1                43.429                   52.631                   47.368
# 2                    42                   51.099                   48.901
#
#   FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.  \
# 0                                                  0
# 1                                                2.3
# 2                                                0.9
#
#                          Title
# 0  2018-2019 NBA Referee Stats
# 1  2018-2019 NBA Referee Stats
# 2  2018-2019 NBA Referee Stats
#   RANK       REFEREE  TYPE EXPERIENCE\n(YEARS) GAMES OFFICIATED  \
# 0    1    Ben Taylor  MAIN                   6                1
# 1    2  Bennie Adams  MAIN                  22               35
# 2    3  Bill Kennedy  MAIN                  22               31
#
#   HOME TEAM WIN% HOME TEAM POINTS DIFFERENTIAL TOTAL POINTS PER GAME  \
# 0              1                             6                   202
# 1          0.514                           1.7                 212.9
# 2          0.581                           2.8                 209.6
#
#   CALLED FOULS PER GAME FOUL% AGAINST ROAD TEAMS FOUL% AGAINST HOME TEAMS  \
# 0                    39                     53.8                     46.2
# 1                  41.5                     49.8                     50.2
# 2                  39.4                       51                       49
#
#   FOUL DIFFERENTIALFoul Differential Per GameSeason average of {Called Fouls Against Road Team} - {Called Fouls Against Home Team}. When foul differential is in positive figure, that referee (a.k.a. homey) favors home teams and is more prone to call against road teams.  \
# 0                                                  3
# 1                                               -0.1
# 2                                                0.8
#
#                          Title
# 0  2017-2018 NBA Referee Stats
# 1  2017-2018 NBA Referee Stats
# 2  2017-2018 NBA Referee Stats

# %%
url_test_preseason = 'https://www.espn.com/nba/team/schedule/_/name/den/season/2024/seasontype/2'
dataFrame_title = 'title'

# Open the URL and read the HTML content
response = request.urlopen(url_test_preseason)
html = response.read()

# Create BeautifulSoup object to parse the HTML
soup = bs4.BeautifulSoup(html, "lxml")

# Find the <table> tag
table_tag = soup.find('table')
table_soup = bs4.BeautifulSoup(str(table_tag))

# Find the <thead> tag
thead_tag = table_soup.find('thead')
thead_soup = bs4.BeautifulSoup(str(thead_tag))

# Find all the <th> tags within the <thead> tag
th_head_tag = thead_soup.find_all('th')

# Find all the <tr> tags within the <table> tag
tr_tag = table_soup.find_all('tr')

# Get the table lines
lines_list = tr_tag

# Get the column names
tr_soup = bs4.BeautifulSoup(str(lines_list[1]))
td_tags = tr_soup.find_all('td')
columns_name = []
for td in td_tags:
    attribute = td.get_text()
    columns_name.append(attribute)

# Get the data
data = [] 
for tr in lines_list[2:]:
    tr_soup = bs4.BeautifulSoup(str(tr))
    td_tags = tr_soup.find_all('td')
    
    if len(td_tags) < len(columns_name): # Get only the informations we want
        break

    attributes = []
    for td in td_tags:
        attribute = td.get_text()
        attributes.append(attribute)

    data.append(attributes)


# Get the data into a dataframe
data_array = np.asarray(data)
df = pd.DataFrame(data, columns=columns_name)

# Add the Title of the dataframe 
df['Title'] = dataFrame_title # This will add the title in each column
